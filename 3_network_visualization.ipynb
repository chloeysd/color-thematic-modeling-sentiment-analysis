# %%
#create networkx graph,as Ref: https://blog.csdn.net/weston95/article/details/132620651
#I change the way of representing weights, from using the thickness of edges in the reference to using the area of nodes, which is more prominent.
import networkx as nx
import matplotlib.pyplot as plt

#retrieve topics, keywords and their weights
topics_and_keywords = {
"Topic 0":{"person": 65.63,"expression": 67.78,"rome": 70.99,"emotional": 72.18,"social": 82.93,"theory": 90.72,"roman": 129.40,"war": 175.00,"anger": 314.19,"emotion": 346.10},
"Topic 1":{"goal": 52.25,"psychologist": 52.46,"research": 55.62,"chariot": 71.67,"performance": 93.83,"ferrari": 114.20,"psychology": 152.14,"race": 165.48,"athlete": 177.20,"sport": 309.06},
"Topic 2":{"area": 68.55,"system": 77.41,"classic": 80.12,"power": 87.50,"high": 93.99,"period": 108.20,"chinese": 146.52,"maya": 302.20,"laser": 305.20,"china": 381.92},
"Topic 3":{"vermilion": 61.20,"national": 64.19,"surface": 67.61,"association": 69.13,"player": 73.39,"planet": 74.92,"scarlet": 91.61,"earth": 94.22,"football": 114.20,"mar": 230.10},
"Topic 4":{"body": 58.27,"star": 62.20,"thermodynamic": 77.20,"culture": 83.73,"dwarf": 84.20,"temperature": 92.04,"system": 93.12,"transfer": 101.20,"energy": 118.43,"heat": 206.06}
}

#custom topic colors to ensure keywords in the same topic display the same color
colors = {
    "Topic 0": "#fa757c",
    "Topic 1": "#e02d36",
    "Topic 2": "#6b0308",
    "Topic 3": "#ab030c",
    "Topic 4": "#ff000d"
}

#creat nodes
nodes = [keyword for topic_keywords in topics_and_keywords.values() for keyword in topic_keywords]
#create a graph
G = nx.Graph()
#add a central node
G.add_node('red', weight=500, color='red') 

#loop through each topic in topics_and_keywords and add nodes&edges to the graph for corresponding keywords and weights
for topic,keywords in topics_and_keywords.items():
    for keyword, weight in keywords.items():
        #add a node for each keyword in graph G, with the node color based on the keyword's weight
        G.add_node(keyword, weight=weight, color=colors[topic])  
        #create an edge for each keyword connected to the central 'red' node, indicating a network centered around 'red'
        G.add_edge('red', keyword, weight=weight) 

#custom node sizes & weights, as Ref:https://stackoverflow.com/questions/56294715/networkx-graph-plot-node-weights
#I made modifications to represent weights by node area instead of labels by defining node_sizes 
node_sizes = [G.nodes[n]['weight'] * 10 for n in G.nodes]#multiplied by 10 to enhance visibility
#use custom colors for nodes to differentiate topics
node_colors = [G.nodes[n]['color'] for n in G.nodes]
#set all edge widths to 1
edge_widths = 1

#draw the network graph, set image size and background
plt.figure(figsize=(15, 15)) 
plt.style.use('dark_background') 
#add a title and turn off the axis for aesthetic
plt.title('Network Visualization with Central "red" Node', fontsize=20, color='white') 
plt.axis('off')

#set node layout, customize node color and font size
pos = nx.spring_layout(G, seed=42)
nx.draw_networkx_nodes(G, pos, node_size=node_sizes, node_color=node_colors,edgecolors='#ffffff')
nx.draw_networkx_edges(G, pos, width=edge_widths,edge_color='#ffffff')
nx.draw_networkx_labels(G, pos, font_size=10, font_color="white") 

#save the graph
save_path = '/Users/yinshuodi/Desktop/mini-project-23006440/Webcrawling/image/red/red_network.png'  
plt.savefig(save_path, format='png', bbox_inches='tight',dpi=300)

plt.show()

# %% [markdown]
# Due to the abundance of keywords and color definitions for each color, I didn't include them all in one code.
#
# Using the same code, I modified topics_and_keywords and colors for each color, resulting in separate network graphs. These graphs are then saved in their respective color image folders for convenient future use.

# %%
topics_and_keywords = {
"Topic 0":{"show": 41.66,"theory": 42.12,"cup": 44.20,"pigment": 45.17,"produce": 46.17,"study": 47.20,"different": 48.54,"pumpkin": 95.20,"netherland": 107.20,"carrot": 112.20},
"Topic 1":{"write": 39.20,"hallow": 39.20,"know": 44.20,"period": 49.20,"kingdom": 58.20,"rgb": 58.20,"ancient": 88.20,"egypt": 100.20,"halloween": 112.20,"egyptian": 155.20},
"Topic 2":{"rock": 27.20,"area": 29.20,"autumn": 33.19,"arche": 34.19,"record": 40.45,"data": 41.20,"park": 51.18,"aircraft": 58.35,"flight": 74.20,"recorder": 76.20},
"Topic 3":{"subcontinent": 58.20,"period": 59.08,"kingdom": 60.20,"dynasty": 63.20,"rule": 71.19,"british": 75.20,"spice": 82.80,"empire": 124.20,"indian": 149.20,"india": 210.09},
"Topic 4":{"fly": 13.20,"flown": 13.20,"united": 13.82,"design": 14.20,"signal": 14.20,"pole": 15.20,"pigment": 16.01,"flagpole": 29.20,"national": 29.69,"orpiment": 49.18}
}

colors = {
    "Topic 0": "#663f04",
    "Topic 1": "#dea754",
    "Topic 2": "#ff9e0d",
    "Topic 3": "#ba7307",
    "Topic 4": "#f2c683"
}

nodes = [keyword for topic_keywords in topics_and_keywords.values() for keyword in topic_keywords]
G = nx.Graph()
G.add_node('orange', weight=500, color='#ffa500')

for topic,keywords in topics_and_keywords.items():
    for keyword, weight in keywords.items():
        G.add_node(keyword, weight=weight, color=colors[topic])  
        G.add_edge('orange', keyword, weight=weight) 

node_sizes = [G.nodes[n]['weight'] * 10 for n in G.nodes]
node_colors = [G.nodes[n]['color'] for n in G.nodes]
edge_widths = 1

plt.figure(figsize=(15, 15)) 
plt.style.use('dark_background') 
plt.title('Network Visualization with Central "orange" Node', fontsize=20, color='white') 
plt.axis('off')

pos = nx.spring_layout(G, seed=42)
nx.draw_networkx_nodes(G, pos, node_size=node_sizes, node_color=node_colors,edgecolors='#ffffff')
nx.draw_networkx_edges(G, pos, width=edge_widths,edge_color='#ffffff')
nx.draw_networkx_labels(G, pos, font_size=10, font_color="black") 

save_path = '/Users/yinshuodi/Desktop/mini-project-23006440/Webcrawling/image/orange/orange_network.png'  
plt.savefig(save_path, format='png', bbox_inches='tight',dpi=300)

plt.show()

# %%
topics_and_keywords ={
    "Topic 0": {"object": 32.20,"earth": 35.20,"yolk": 42.20, "sun": 46.19,"sunlight": 46.20,"egg": 47.20, "wave": 49.20,"solar": 50.20,"theory": 51.20,"radiation": 57.20},
    "Topic 1": {"three": 43.19,"united": 43.70,"know": 45.42,"primarie": 51.20,"rgb": 67.70, "plant": 80.05,"corn": 83.25,"pigment": 90.93,"ochre": 106.20,"maize": 262.96},
    "Topic 2": { "specie": 15.20,"hotel": 16.20,"average": 16.20,"water": 17.20, "nevada": 20.20,"casino": 20.20,"downtown": 27.20,"area": 30.20,"city": 72.20,"vega": 131.20},
    "Topic 3": {"high": 111.92,"country": 115.21,"period": 121.11,"empire": 135.12,"pleasure": 135.20,"egyptian": 162.21,"chinese": 168.20,"egypt": 258.21,"china": 425.13,"gold": 451.20},
    "Topic 4": {"point": 58.20,"taxicab": 70.20,"classification": 94.20,"jersey": 99.20,"france": 144.20,"race": 146.20,"stage": 146.20,"rider": 171.20,"taxi": 175.20,"tour": 305.20}
}

#custom topic colors to ensure keywords in the same topic display the same color
colors = {
    "Topic 0": "#f5ef89",
    "Topic 1": "#7a7604",
    "Topic 2": "#fff312",
    "Topic 3": "#b5ac09",
    "Topic 4": "#757006"
}

nodes = [keyword for topic_keywords in topics_and_keywords.values() for keyword in topic_keywords]
G = nx.Graph()
G.add_node('yellow', weight=500, color='yellow')

for topic,keywords in topics_and_keywords.items():
    for keyword, weight in keywords.items():
        G.add_node(keyword, weight=weight, color=colors[topic])  
        G.add_edge('yellow', keyword, weight=weight) 

node_sizes = [G.nodes[n]['weight'] * 10 for n in G.nodes]
node_colors = [G.nodes[n]['color'] for n in G.nodes]
edge_widths = 1

plt.figure(figsize=(15, 15)) 
plt.style.use('dark_background') 
plt.title('Network Visualization with Central "yellow" Node', fontsize=20, color='white') 
plt.axis('off')

pos = nx.spring_layout(G, seed=42)
nx.draw_networkx_nodes(G, pos, node_size=node_sizes, node_color=node_colors,edgecolors='#ffffff')
nx.draw_networkx_edges(G, pos, width=edge_widths,edge_color='#ffffff')
nx.draw_networkx_labels(G, pos, font_size=10, font_color="black") 

save_path = '/Users/yinshuodi/Desktop/mini-project-23006440/Webcrawling/image/yellow/yellow_network.png'  
plt.savefig(save_path, format='png', bbox_inches='tight',dpi=300)

plt.show()

# %%
topics_and_keywords_green = {
    "Topic 0": {"meaning": 22.20,"emotion": 23.20,"painting": 23.20,"goal": 24.20,"modern": 25.20,"historian": 25.20,"object": 25.20,"artist": 40.20,"hope": 98.20,"envy": 102.20},
    "Topic 1": {"animal": 40.69,"nature": 43.20,"water": 43.69,"natural": 45.75,"human": 47.29,"organism": 49.36,"cell": 61.41,"earth": 71.25,"emerald": 83.20,"life": 127.73},
    "Topic 2": {"disease": 36.20, "babylonian": 42.20,"technique": 44.20,"mesopotamia": 49.20,"waza": 50.20, "youth": 53.20,"age": 76.20,"casino": 98.20,"judo": 122.20,"health": 174.20},
    "Topic 3": {"modern": 55.20,"word": 62.20,"three": 64.20,"asia": 64.20,"pigment": 65.20,"system": 66.20,"rgb": 71.20,"europe": 72.20,"empire": 87.20},
    "Topic 4": {"theory": 69.20,"different": 72.15,"carbon": 85.14,"photosynthesi": 86.15,"reaction": 95.20, "chlorophyll": 115.20,"signal": 171.20,"traffic": 185.20,"plant": 254.31,"emotion": 316.20}
}

colors = {
    "Topic 0": "#4d7056",
    "Topic 1": "#5bba73",
    "Topic 2": "#08c738",
    "Topic 3": "#057d23",
    "Topic 4": "#02360f"
}

nodes = [keyword for topic_keywords in topics_and_keywords.values() for keyword in topic_keywords]
G = nx.Graph()
G.add_node('green', weight=500, color='green')

for topic,keywords in topics_and_keywords.items():
    for keyword, weight in keywords.items():
        G.add_node(keyword, weight=weight, color=colors[topic])  
        G.add_edge('green', keyword, weight=weight) 

node_sizes = [G.nodes[n]['weight'] * 10 for n in G.nodes]
node_colors = [G.nodes[n]['color'] for n in G.nodes]
edge_widths = 1

plt.figure(figsize=(15, 15)) 
plt.style.use('dark_background') 
plt.title('Network Visualization with Central "green" Node', fontsize=20, color='white') 
plt.axis('off')

pos = nx.spring_layout(G, seed=42)
nx.draw_networkx_nodes(G, pos, node_size=node_sizes, node_color=node_colors,edgecolors='#ffffff')
nx.draw_networkx_edges(G, pos, width=edge_widths,edge_color='#ffffff')
nx.draw_networkx_labels(G, pos, font_size=10, font_color="white") 

save_path = '/Users/yinshuodi/Desktop/mini-project-23006440/Webcrawling/image/green/green_network.png'  
plt.savefig(save_path, format='png', bbox_inches='tight',dpi=300)

plt.show()

# %%
topics_and_keywords= {
    "Topic 0": { "show": 29.38, "atmosphere": 30.35, "cloud": 30.90, "product": 33.20, "film": 34.20, "cinecolor": 35.20, "ring": 35.20, "different": 36.38, "planet": 72.67, "uranu": 150.19},
    "Topic 1": {"high": 39.20, "oil": 39.20, "methane": 41.20, "fuel": 42.20, "ancient": 45.20,  "food": 60.20, "stove": 71.20, "cooking": 77.20, "greek": 85.20, "natural": 161.20},
    "Topic 2": {"cyanide": 10.20, "pb": 10.20, "ferrocyanide": 10.20, "ion": 10.20, "cn": 11.20,  "teal": 15.20, "iron": 16.20, "fe": 19.20, "pigment": 24.20, "prussian": 57.20},
    "Topic 3": {"surface": 45.50, "air": 46.72, "pressure": 50.09, "high": 52.52, "lapi": 58.20, "cyanotype": 83.20, "temperature": 87.89, "atmosphere": 97.44, "earth": 99.89, "water": 507.63},
    "Topic 4": {"organism": 37.20, "human": 38.20, "visible": 40.08, "produce": 40.60, "spectrum": 44.10, "specie": 50.08, "flame": 59.20, "bacterial": 60.20, "cell": 99.20, "bacteria": 198.20}
}

colors = {
    "Topic 0": "#033738",
    "Topic 1": "#24fbff",
    "Topic 2": "#0bd0d4",
    "Topic 3": "#068f91",
    "Topic 4": "#02494a"
}

nodes = [keyword for topic_keywords in topics_and_keywords.values() for keyword in topic_keywords]
G = nx.Graph()
G.add_node('cyan', weight=500, color='cyan')

for topic,keywords in topics_and_keywords.items():
    for keyword, weight in keywords.items():
        G.add_node(keyword, weight=weight, color=colors[topic])  
        G.add_edge('cyan', keyword, weight=weight) 

node_sizes = [G.nodes[n]['weight'] * 10 for n in G.nodes]
node_colors = [G.nodes[n]['color'] for n in G.nodes]
edge_widths = 1

plt.figure(figsize=(15, 15)) 
plt.style.use('dark_background') 
plt.title('Network Visualization with Central "cyan" Node', fontsize=20, color='white') 
plt.axis('off')

pos = nx.spring_layout(G, seed=42)
nx.draw_networkx_nodes(G, pos, node_size=node_sizes, node_color=node_colors,edgecolors='#ffffff')
nx.draw_networkx_edges(G, pos, width=edge_widths,edge_color='#ffffff')
nx.draw_networkx_labels(G, pos, font_size=10, font_color="white") 

save_path = '/Users/yinshuodi/Desktop/mini-project-23006440/Webcrawling/image/cyan/cyan_network.png'  
plt.savefig(save_path, format='png', bbox_inches='tight',dpi=300)

plt.show()

# %%
topics_and_keywords = {
    "Topic 0": {"kingdom": 43.95, "western": 47.88, "period": 50.18, "middle": 58.12, "age": 60.67,  "empire": 65.95, "roman": 66.97, "europe": 71.44, "santorini": 77.20, "island": 99.57},
    "Topic 1": { "device": 68.20, "rgb": 75.91, "ocean": 83.20, "pigment": 88.33, "ultramarine": 97.20, "high": 110.19, "algae": 127.20, "violet": 129.56, "water": 139.95, "sea": 218.52},
    "Topic 2": {"effect": 27.28, "rayleigh": 33.20, "sadnes": 35.19, "ware": 47.20, "wavelength": 48.94,  "chinese": 50.34, "particle": 51.60, "porcelain": 60.20, "sky": 79.75, "scatter": 101.02},
    "Topic 3": {"uniform": 55.61, "high": 60.82, "shot": 62.20, "national": 72.37, "country": 75.40, "argentine": 94.20, "ball": 109.20, "basketball": 111.19, "player": 126.20, "argentina": 146.15},
    "Topic 4": {"pigment": 28.64, "preference": 29.20, "flagpole": 29.20, "product": 35.52, "sun": 36.36, "crystal": 39.20, "different": 39.33, "sky": 40.94, "primarie":44.10,"halo": 52.13}
}

colors = {
    "Topic 0": "#21daff",
    "Topic 1": "#568cf0",
    "Topic 2": "#19b6ff",
    "Topic 3": "#0059ff",
    "Topic 4": "#02546b"
}

nodes = [keyword for topic_keywords in topics_and_keywords.values() for keyword in topic_keywords]
G = nx.Graph()
G.add_node('blue', weight=500, color='blue')

for topic,keywords in topics_and_keywords.items():
    for keyword, weight in keywords.items():
        G.add_node(keyword, weight=weight, color=colors[topic])  
        G.add_edge('blue', keyword, weight=weight) 

node_sizes = [G.nodes[n]['weight'] * 10 for n in G.nodes]
node_colors = [G.nodes[n]['color'] for n in G.nodes]
edge_widths = 1

plt.figure(figsize=(15, 15)) 
plt.style.use('dark_background') 
plt.title('Network Visualization with Central "blue" Node', fontsize=20, color='white') 
plt.axis('off')

pos = nx.spring_layout(G, seed=42)
nx.draw_networkx_nodes(G, pos, node_size=node_sizes, node_color=node_colors,edgecolors='#ffffff')
nx.draw_networkx_edges(G, pos, width=edge_widths,edge_color='#ffffff')
nx.draw_networkx_labels(G, pos, font_size=10, font_color="white") 

save_path = '/Users/yinshuodi/Desktop/mini-project-23006440/Webcrawling/image/blue/blue_network.png'  
plt.savefig(save_path, format='png', bbox_inches='tight',dpi=300)

plt.show()

# %%
topics_and_keywords = {
    "Topic 0": {"thread": 15.20, "pigment": 19.20, "cocoon": 21.20, "produce": 24.20, "manganese": 25.20, "fiber": 25.20, "production": 28.20, "silkworm": 34.20, "violet": 35.20, "silk": 240.20},
    "Topic 1": {"hematite": 63.20, "greek": 65.75, "woman": 78.94, "roman": 85.92, "dye": 88.52, "constantinople": 95.20, "emperor": 98.66, "violet": 154.20, "empire": 197.04, "byzantine": 200.20},
    "Topic 2": {"win": 30.20, "week": 30.20, "blackberry": 32.20, "playoff": 33.20, "blackberrie": 35.20, "record": 41.20, "nfl": 46.20, "baltimore": 89.20, "season": 89.20, "raven": 167.20 },
    "Topic 3": {"award": 46.20, "franchise": 48.20, "polari": 60.20, "star": 90.20, "club": 100.20, "nba": 118.20, "fremantle": 121.20, "player": 127.20, "league": 128.20, "season": 156.20},
    "Topic 4": {"dynasty": 47.20, "high": 48.10, "artist": 48.23, "million": 50.20, "national": 56.06, "country": 72.03, "impressionist": 80.16, "dye": 141.56, "chinese": 146.98, "china": 383.09}
}

colors = {
    "Topic 0": "#ac78f0",
    "Topic 1": "#8e3ef7",
    "Topic 2": "#6605e6",
    "Topic 3": "#4805a1",
    "Topic 4": "#190238"
}

nodes = [keyword for topic_keywords in topics_and_keywords.values() for keyword in topic_keywords]
G = nx.Graph()
G.add_node('purple', weight=500, color='purple')

for topic,keywords in topics_and_keywords.items():
    for keyword, weight in keywords.items():
        G.add_node(keyword, weight=weight, color=colors[topic])  
        G.add_edge('purple', keyword, weight=weight) 

node_sizes = [G.nodes[n]['weight'] * 10 for n in G.nodes]
node_colors = [G.nodes[n]['color'] for n in G.nodes]
edge_widths = 1

plt.figure(figsize=(15, 15)) 
plt.style.use('dark_background') 
plt.title('Network Visualization with Central "purple" Node', fontsize=20, color='white') 
plt.axis('off')

pos = nx.spring_layout(G, seed=42)
nx.draw_networkx_nodes(G, pos, node_size=node_sizes, node_color=node_colors,edgecolors='#ffffff')
nx.draw_networkx_edges(G, pos, width=edge_widths,edge_color='#ffffff')
nx.draw_networkx_labels(G, pos, font_size=10, font_color="white") 

save_path = '/Users/yinshuodi/Desktop/mini-project-23006440/Webcrawling/image/purple/purple_network.png'  
plt.savefig(save_path, format='png', bbox_inches='tight',dpi=300)

plt.show()

# %%
topics_and_keywords = {
    "Topic 0": {"painting": 38.58, "propertie": 38.93, "high": 39.79, "thermal": 43.20, "object": 44.03, "artist": 45.64, "cnt": 46.20, "infrared": 110.98, "carbon": 171.45, "nanotube": 188.20},
    "Topic 1": {"night": 60.80, "source": 66.03, "spectrum": 71.26, "lamp": 81.19, "mourn": 87.15,  "ultraviolet": 107.16, "visible": 109.00, "wavelength": 130.97, "radiation": 170.51, "uv": 275.20},
    "Topic 2": { "begin": 95.62, "practice": 100.77, "public": 104.14, "religion": 109.92, "term": 115.52, "empire": 128.52, "friday": 133.20, "enlightenment": 222.02, "roman": 222.41, "magic": 269.71},
    "Topic 3": {"belief": 55.59, "pigment": 56.22, "witch": 57.72, "player": 86.20, "union": 89.15, "ball": 102.63, "grey": 110.96, "witchcraft": 139.61, "death": 199.73, "rugby": 249.20},
    "Topic 4": {"term": 43.53, "western": 48.82, "empire": 59.20, "dark": 61.56, "roman": 66.20, "europe": 71.11, "middle": 72.12, "period": 75.20, "evil": 136.13, "age": 137.20}
}

colors = {
    "Topic 0": "#b5b1b5",
    "Topic 1": "#9e9e9b",
    "Topic 2": "#757573",
    "Topic 3": "#3b3b39",
    "Topic 4": "#0f0f0f"
}

nodes = [keyword for topic_keywords in topics_and_keywords.values() for keyword in topic_keywords]
G = nx.Graph()
G.add_node('black', weight=500, color='black')

for topic,keywords in topics_and_keywords.items():
    for keyword, weight in keywords.items():
        G.add_node(keyword, weight=weight, color=colors[topic])  
        G.add_edge('black', keyword, weight=weight) 

node_sizes = [G.nodes[n]['weight'] * 10 for n in G.nodes]
node_colors = [G.nodes[n]['color'] for n in G.nodes]
edge_widths = 1

plt.figure(figsize=(15, 15)) 
plt.style.use('dark_background') 
plt.title('Network Visualization with Central "black" Node', fontsize=20, color='white') 
plt.axis('off')

pos = nx.spring_layout(G, seed=42)
nx.draw_networkx_nodes(G, pos, node_size=node_sizes, node_color=node_colors,edgecolors='white')
nx.draw_networkx_edges(G, pos, width=edge_widths,edge_color='white')
nx.draw_networkx_labels(G, pos, font_size=10, font_color="white") 

save_path = '/Users/yinshuodi/Desktop/mini-project-23006440/Webcrawling/image/black/black_network.png'  
plt.savefig(save_path, format='png', bbox_inches='tight',dpi=300)

plt.show()

# %%
topics_and_keywords = {
    "Topic 0": {"order": 53.19, "doric": 55.20, "ionic": 59.20, "different": 59.99, "nao": 69.20, "roman": 77.19, "building": 80.70, "greek": 98.18, "column": 164.77, "temple": 371.19},
    "Topic 1": {"animal": 45.68, "specie": 51.44, "population": 54.00, "culture": 63.44, "chalk": 70.29, "water": 72.90, "sea": 93.76, "whale": 116.19, "beluga": 239.20, "pearl": 398.20},
    "Topic 2": {"radiation": 51.10, "ice": 53.19, "visible": 54.98, "ray": 61.97, "cumulu": 64.20, "wavelength": 66.51, "spectrum": 74.89, "water": 76.42, "cloud": 146.86, "snow": 246.19},
    "Topic 3": {"built": 59.10, "city": 60.14, "modernist": 62.16, "house": 92.12, "architect": 103.08,  "design": 125.01, "style": 138.09, "penguin": 158.20, "architecture": 163.00, "building": 201.68},
    "Topic 4": {"belief": 37.20, "human": 37.33, "fat": 39.26, "protein": 39.46, "soul": 42.20, "dead": 44.95, "cow": 48.29, "spirit": 84.75, "ghost": 215.50, "milk": 353.11}
}

colors = {
    "Topic 0": "#fcfcf7",
    "Topic 1": "#e3e3de",
    "Topic 2": "#b3b2b1",
    "Topic 3": "#7d7d7a",
    "Topic 4": "#4d4c4b"
}

nodes = [keyword for topic_keywords in topics_and_keywords.values() for keyword in topic_keywords]
G = nx.Graph()
G.add_node('white', weight=500, color='white')

for topic,keywords in topics_and_keywords.items():
    for keyword, weight in keywords.items():
        G.add_node(keyword, weight=weight, color=colors[topic])  
        G.add_edge('white', keyword, weight=weight) 

node_sizes = [G.nodes[n]['weight'] * 10 for n in G.nodes]
node_colors = [G.nodes[n]['color'] for n in G.nodes]
edge_widths = 1

plt.figure(figsize=(15, 15)) 
plt.style.use('dark_background') 
plt.title('Network Visualization with Central "white" Node', fontsize=20, color='white') 
plt.axis('off')

pos = nx.spring_layout(G, seed=42)
nx.draw_networkx_nodes(G, pos, node_size=node_sizes, node_color=node_colors,edgecolors='#ffffff')
nx.draw_networkx_edges(G, pos, width=edge_widths,edge_color='#ffffff')
nx.draw_networkx_labels(G, pos, font_size=10, font_color="black") 

save_path = '/Users/yinshuodi/Desktop/mini-project-23006440/Webcrawling/image/white/white_network.png'  
plt.savefig(save_path, format='png', bbox_inches='tight',dpi=300)

plt.show()

# %%
topics_and_keywords = {
    "Topic 0": {"lead": 24.13, "woman": 24.18, "cosmetic": 24.20, "pigment": 25.20, "lip": 27.20, "associate": 32.03, "boy": 41.20, "girl": 59.36, "magenta": 65.20, "lipstick": 128.20},
    "Topic 1": {"manganese": 8.20, "food": 8.20, "stand": 8.20, "specie": 8.20, "chick": 9.20, "nest": 10.20, "tongue": 11.20, "rhodochrosite": 14.20, "bird": 15.20, "flamingo": 65.20},
    "Topic 2": {"presl": 26.20, "hamilton": 26.20, "specie": 28.23, "blossom": 29.07, "angiosperm": 29.20, "william": 50.20, "flower": 73.45, "nelson": 83.20, "plant": 89.20, "emma": 130.20},
    "Topic 3": {"artist": 28.20, "meaning": 28.20, "different": 31.20, "show": 31.20, "object": 32.20, "product": 33.20, "study": 37.20, "inter": 43.20, "club": 43.20, "miami": 77.20},
    "Topic 4": {"serie": 78.20, "child": 83.54, "social": 85.08, "club": 88.20, "sex": 98.20, "palermo": 101.20, "doll": 133.20, "barbie": 149.20, "toy": 227.01, "gender": 341.91}
}

colors = {
    "Topic 0": "#e474e8",
    "Topic 1": "#ff00ea",
    "Topic 2": "#910385",
    "Topic 3": "#4f0249",
    "Topic 4": "#eb17d5"
}

nodes = [keyword for topic_keywords in topics_and_keywords.values() for keyword in topic_keywords]
G = nx.Graph()
G.add_node('pink', weight=500, color='#b63fd4')

for topic,keywords in topics_and_keywords.items():
    for keyword, weight in keywords.items():
        G.add_node(keyword, weight=weight, color=colors[topic])  
        G.add_edge('pink', keyword, weight=weight) 

node_sizes = [G.nodes[n]['weight'] * 10 for n in G.nodes]
node_colors = [G.nodes[n]['color'] for n in G.nodes]
edge_widths = 1

plt.figure(figsize=(15, 15)) 
plt.style.use('dark_background') 
plt.title('Network Visualization with Central "pink" Node', fontsize=20, color='white') 
plt.axis('off')

pos = nx.spring_layout(G, seed=42)
nx.draw_networkx_nodes(G, pos, node_size=node_sizes, node_color=node_colors,edgecolors='#ffffff')
nx.draw_networkx_edges(G, pos, width=edge_widths,edge_color='#ffffff')
nx.draw_networkx_labels(G, pos, font_size=10, font_color="white") 

save_path = '/Users/yinshuodi/Desktop/mini-project-23006440/Webcrawling/image/pink/pink_network.png'  
plt.savefig(save_path, format='png', bbox_inches='tight',dpi=300)

plt.show()
